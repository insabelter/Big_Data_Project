# %% [markdown]
# # Vergleich zweier Graphen
#
# Korrelation zwischen zwei Variablen
# --> numpy

# %%
import numpy as np

# %% [markdown]
# ## Test mit Fußgängern und Inzidenzen (Münchens)

# %% [markdown]
# ### Dictionary mit Fußgängern und Fällen nach Datum

# %%
from pymongo import MongoClient
import datetime as dt

client = MongoClient('mongodb://localhost:27017/')

pedestrians = client.pedcov.pedestrians
incidences = client.pedcov.incidences

# dic:  {date: [pedstrians, covid count]}
dic = {}

# pedestrians (only München)
for row in pedestrians.aggregate(
    [{
    "$match": {"location": "Kaufingerstraße, München"}
    }]):
    if row['time of measurement'] != 'time of me':
        date = dt.datetime.strptime(row['time of measurement'], '%Y-%m-%d').date()
        dic[date] = [int(row['pedestrians count'])]


# incidences (only München, NeuerFall in (0, 1)) -> aggregiert nach Meldedatum (Summe Fälle)
for row in incidences.aggregate(
    [{
        "$match": 
            {"$and":
             [
                 {"Landkreis": "SK München"},
                 {"$or": [{"Neuer Fall": "0"}, {"Neuer Fall": "1"}]}
             ]
            }
    },
    {
        "$group": {"_id": "$Meldedatum","Fälle": {"$sum": "$Anzahl Fall"}}
    }]):
    date = dt.datetime.strptime(row['_id'], '%Y-%m-%d').date()
    dic[date].append(int(row['Fälle']))

# add 0 where no incidences
d = {}
for k in dic:
    l = dic[k]
    if len(l) == 1:
        l.append(0)
    d[k] = l

dic = d

dic
# Out:
# {datetime.date(2020, 1, 1): [61896, 0],
#  datetime.date(2020, 1, 2): [128865, 0],
#  datetime.date(2020, 1, 3): [123737, 0],
#  datetime.date(2020, 1, 4): [118112, 0],
#  datetime.date(2020, 1, 5): [35286, 0],
#  datetime.date(2020, 1, 6): [33596, 0],
#  datetime.date(2020, 1, 7): [56079, 0],
#  datetime.date(2020, 1, 8): [62615, 0],
#  datetime.date(2020, 1, 9): [69690, 0],
#  datetime.date(2020, 1, 10): [79217, 0],
#  datetime.date(2020, 1, 11): [114360, 0],
#  datetime.date(2020, 1, 12): [29366, 0],
#  datetime.date(2020, 1, 13): [60058, 0],
#  datetime.date(2020, 1, 14): [61250, 0],
#  datetime.date(2020, 1, 15): [63147, 0],
#  datetime.date(2020, 1, 16): [62923, 0],
#  datetime.date(2020, 1, 17): [78998, 0],
#  datetime.date(2020, 1, 18): [102862, 0],
#  datetime.date(2020, 1, 19): [24408, 0],
#  datetime.date(2020, 1, 20): [54335, 0],
#  datetime.date(2020, 1, 21): [54053, 0],
#  datetime.date(2020, 1, 22): [54618, 0],
#  datetime.date(2020, 1, 23): [55530, 0],
#  datetime.date(2020, 1, 24): [79833, 0],
#  datetime.date(2020, 1, 25): [129792, 0],
#  datetime.date(2020, 1, 26): [34853, 0],
#  datetime.date(2020, 1, 27): [66645, 0],
#  datetime.date(2020, 1, 28): [50555, 0],
#  datetime.date(2020, 1, 29): [51021, 1],
#  datetime.date(2020, 1, 30): [63922, 0],
#  datetime.date(2020, 1, 31): [78096, 0],
#  datetime.date(2020, 2, 1): [112521, 0],
#  datetime.date(2020, 2, 2): [24151, 0],
#  datetime.date(2020, 2, 3): [25703, 1],
#  datetime.date(2020, 2, 4): [50787, 0],
#  datetime.date(2020, 2, 5): [59510, 0],
#  datetime.date(2020, 2, 6): [66272, 0],
#  datetime.date(2020, 2, 7): [76522, 0],
#  datetime.date(2020, 2, 8): [126053, 0],
#  datetime.date(2020, 2, 9): [39330, 0],
#  datetime.date(2020, 2, 10): [44170, 0],
#  datetime.date(2020, 2, 11): [45317, 1],
#  datetime.date(2020, 2, 12): [55543, 0],
#  datetime.date(2020, 2, 13): [67561, 0],
#  datetime.date(2020, 2, 14): [82958, 0],
#  datetime.date(2020, 2, 15): [127401, 0],
#  datetime.date(2020, 2, 16): [45770, 0],
#  datetime.date(2020, 2, 17): [62886, 0],
#  datetime.date(2020, 2, 18): [63489, 0],
#  datetime.date(2020, 2, 19): [56084, 0],
#  datetime.date(2020, 2, 20): [69289, 0],
#  datetime.date(2020, 2, 21): [85707, 0],
#  datetime.date(2020, 2, 22): [133730, 0],
#  datetime.date(2020, 2, 23): [51022, 0],
#  datetime.date(2020, 2, 24): [85119, 0],
#  datetime.date(2020, 2, 25): [87780, 0],
#  datetime.date(2020, 2, 26): [61274, 0],
#  datetime.date(2020, 2, 27): [58179, 0],
#  datetime.date(2020, 2, 28): [77330, 2],
#  datetime.date(2020, 2, 29): [110905, 0],
#  datetime.date(2020, 3, 1): [31293, 0],
#  datetime.date(2020, 3, 2): [56225, 3],
#  datetime.date(2020, 3, 3): [46077, 1],
#  datetime.date(2020, 3, 4): [53560, 3],
#  datetime.date(2020, 3, 5): [43191, 2],
#  datetime.date(2020, 3, 6): [65908, 13],
#  datetime.date(2020, 3, 7): [106850, 0],
#  datetime.date(2020, 3, 8): [37137, 0],
#  datetime.date(2020, 3, 9): [48947, 23],
#  datetime.date(2020, 3, 10): [26483, 31],
#  datetime.date(2020, 3, 11): [54462, 22],
#  datetime.date(2020, 3, 12): [50911, 18],
#  datetime.date(2020, 3, 13): [47834, 48],
#  datetime.date(2020, 3, 14): [64623, 64],
#  datetime.date(2020, 3, 15): [16109, 19],
#  datetime.date(2020, 3, 16): [34012, 67],
#  datetime.date(2020, 3, 17): [23879, 144],
#  datetime.date(2020, 3, 18): [13469, 212],
#  datetime.date(2020, 3, 19): [10249, 173],
#  datetime.date(2020, 3, 20): [8438, 195],
#  datetime.date(2020, 3, 21): [1334, 176],
#  datetime.date(2020, 3, 22): [2313, 88],
#  datetime.date(2020, 3, 23): [4407, 94],
#  datetime.date(2020, 3, 24): [4304, 170],
#  datetime.date(2020, 3, 25): [4116, 239],
#  datetime.date(2020, 3, 26): [4631, 257],
#  datetime.date(2020, 3, 27): [5727, 258],
#  datetime.date(2020, 3, 28): [5278, 139],
#  datetime.date(2020, 3, 29): [2932, 178],
#  datetime.date(2020, 3, 30): [4421, 113],
#  datetime.date(2020, 3, 31): [5089, 310],
#  datetime.date(2020, 4, 1): [5649, 231],
#  datetime.date(2020, 4, 2): [5935, 143],
#  datetime.date(2020, 4, 3): [5734, 178],
#  datetime.date(2020, 4, 4): [5381, 135],
#  datetime.date(2020, 4, 5): [4897, 84],
#  datetime.date(2020, 4, 6): [6775, 118],
#  datetime.date(2020, 4, 7): [6688, 141],
#  datetime.date(2020, 4, 8): [7100, 157],
#  datetime.date(2020, 4, 9): [7141, 112],
#  datetime.date(2020, 4, 10): [5775, 98],
#  datetime.date(2020, 4, 11): [6543, 104],
#  datetime.date(2020, 4, 12): [5602, 72],
#  datetime.date(2020, 4, 13): [5448, 61],
#  datetime.date(2020, 4, 14): [5780, 86],
#  datetime.date(2020, 4, 15): [6937, 108],
#  datetime.date(2020, 4, 16): [7694, 95],
#  datetime.date(2020, 4, 17): [7855, 93],
#  datetime.date(2020, 4, 18): [7400, 46],
#  datetime.date(2020, 4, 19): [6382, 49],
#  datetime.date(2020, 4, 20): [9807, 32],
#  datetime.date(2020, 4, 21): [9980, 55],
#  datetime.date(2020, 4, 22): [9988, 57],
#  datetime.date(2020, 4, 23): [10353, 77],
#  datetime.date(2020, 4, 24): [9148, 56],
#  datetime.date(2020, 4, 25): [10193, 47],
#  datetime.date(2020, 4, 26): [7322, 33],
#  datetime.date(2020, 4, 27): [23944, 80],
#  datetime.date(2020, 4, 28): [18009, 50],
#  datetime.date(2020, 4, 29): [16812, 41],
#  datetime.date(2020, 4, 30): [22815, 44],
#  datetime.date(2020, 5, 1): [6259, 59],
#  datetime.date(2020, 5, 2): [31375, 33],
#  datetime.date(2020, 5, 3): [9209, 25],
#  datetime.date(2020, 5, 4): [29812, 35],
#  datetime.date(2020, 5, 5): [27715, 30],
#  datetime.date(2020, 5, 6): [31586, 19],
#  datetime.date(2020, 5, 7): [32916, 30],
#  datetime.date(2020, 5, 8): [36148, 43],
#  datetime.date(2020, 5, 9): [48109, 24],
#  datetime.date(2020, 5, 10): [8656, 22],
#  datetime.date(2020, 5, 11): [28485, 61],
#  datetime.date(2020, 5, 12): [35017, 27],
#  datetime.date(2020, 5, 13): [24665, 35],
#  datetime.date(2020, 5, 14): [31295, 23],
#  datetime.date(2020, 5, 15): [34125, 18],
#  datetime.date(2020, 5, 16): [61951, 9],
#  datetime.date(2020, 5, 17): [13086, 11],
#  datetime.date(2020, 5, 18): [43778, 7],
#  datetime.date(2020, 5, 19): [41052, 12],
#  datetime.date(2020, 5, 20): [43159, 20],
#  datetime.date(2020, 5, 21): [13898, 19],
#  datetime.date(2020, 5, 22): [57755, 21],
#  datetime.date(2020, 5, 23): [39687, 2],
#  datetime.date(2020, 5, 24): [14518, 6],
#  datetime.date(2020, 5, 25): [39091, 14],
#  datetime.date(2020, 5, 26): [43634, 46],
#  datetime.date(2020, 5, 27): [45833, 34],
#  datetime.date(2020, 5, 28): [40798, 6],
#  datetime.date(2020, 5, 29): [53261, 14],
#  datetime.date(2020, 5, 30): [75818, 33],
#  datetime.date(2020, 5, 31): [18558, 5],
#  datetime.date(2020, 6, 1): [18564, 0],
#  datetime.date(2020, 6, 2): [57448, 5],
#  datetime.date(2020, 6, 3): [52267, 12],
#  datetime.date(2020, 6, 4): [43492, 8],
#  datetime.date(2020, 6, 5): [53867, 14],
#  datetime.date(2020, 6, 6): [66765, 5],
#  datetime.date(2020, 6, 7): [5624, 9],
#  datetime.date(2020, 6, 8): [58022, 13],
#  datetime.date(2020, 6, 9): [49779, 8],
#  datetime.date(2020, 6, 10): [47169, 9],
#  datetime.date(2020, 6, 11): [22470, 2],
#  datetime.date(2020, 6, 12): [77701, 12],
#  datetime.date(2020, 6, 13): [73355, 5],
#  datetime.date(2020, 6, 14): [7289, 11],
#  datetime.date(2020, 6, 15): [17491, 4],
#  datetime.date(2020, 6, 16): [43473, 9],
#  datetime.date(2020, 6, 17): [41477, 13],
#  datetime.date(2020, 6, 18): [53634, 4],
#  datetime.date(2020, 6, 19): [36997, 12],
#  datetime.date(2020, 6, 20): [69728, 22],
#  datetime.date(2020, 6, 21): [21033, 14],
#  datetime.date(2020, 6, 22): [53366, 4],
#  datetime.date(2020, 6, 23): [51328, 18],
#  datetime.date(2020, 6, 24): [51404, 13],
#  datetime.date(2020, 6, 25): [52037, 18],
#  datetime.date(2020, 6, 26): [58561, 17],
#  datetime.date(2020, 6, 27): [78147, 12],
#  datetime.date(2020, 6, 28): [16441, 10],
#  datetime.date(2020, 6, 29): [50309, 21],
#  datetime.date(2020, 6, 30): [56885, 40],
#  datetime.date(2020, 7, 1): [49265, 10],
#  datetime.date(2020, 7, 2): [52524, 23],
#  datetime.date(2020, 7, 3): [71651, 20],
#  datetime.date(2020, 7, 4): [91110, 14],
#  datetime.date(2020, 7, 5): [20657, 4],
#  datetime.date(2020, 7, 6): [61619, 23],
#  datetime.date(2020, 7, 7): [62264, 34],
#  datetime.date(2020, 7, 8): [57320, 21],
#  datetime.date(2020, 7, 9): [57332, 12],
#  datetime.date(2020, 7, 10): [51801, 18],
#  datetime.date(2020, 7, 11): [91532, 3],
#  datetime.date(2020, 7, 12): [25804, 7],
#  datetime.date(2020, 7, 13): [64284, 15],
#  datetime.date(2020, 7, 14): [59800, 12],
#  datetime.date(2020, 7, 15): [57881, 20],
#  datetime.date(2020, 7, 16): [42453, 26],
#  datetime.date(2020, 7, 17): [74188, 26],
#  datetime.date(2020, 7, 18): [98259, 6],
#  datetime.date(2020, 7, 19): [24610, 17],
#  datetime.date(2020, 7, 20): [61470, 10],
#  datetime.date(2020, 7, 21): [61038, 16],
#  datetime.date(2020, 7, 22): [66940, 15],
#  datetime.date(2020, 7, 23): [63573, 16],
#  datetime.date(2020, 7, 24): [75710, 17],
#  datetime.date(2020, 7, 25): [92888, 14],
#  datetime.date(2020, 7, 26): [25480, 2],
#  datetime.date(2020, 7, 27): [70432, 13],
#  datetime.date(2020, 7, 28): [54006, 15],
#  datetime.date(2020, 7, 29): [72958, 17],
#  datetime.date(2020, 7, 30): [63112, 19],
#  datetime.date(2020, 7, 31): [64550, 17],
#  datetime.date(2020, 8, 1): [72538, 11],
#  datetime.date(2020, 8, 2): [19980, 9],
#  datetime.date(2020, 8, 3): [59515, 26],
#  datetime.date(2020, 8, 4): [48079, 18],
#  datetime.date(2020, 8, 5): [81176, 12],
#  datetime.date(2020, 8, 6): [71242, 35],
#  datetime.date(2020, 8, 7): [68897, 19],
#  datetime.date(2020, 8, 8): [82549, 9],
#  datetime.date(2020, 8, 9): [22902, 2],
#  datetime.date(2020, 8, 10): [64717, 29],
#  datetime.date(2020, 8, 11): [64475, 43],
#  datetime.date(2020, 8, 12): [61742, 44],
#  datetime.date(2020, 8, 13): [69610, 55],
#  datetime.date(2020, 8, 14): [78414, 55],
#  datetime.date(2020, 8, 15): [41543, 27],
#  datetime.date(2020, 8, 16): [24541, 48],
#  datetime.date(2020, 8, 17): [74087, 86],
#  datetime.date(2020, 8, 18): [65737, 61],
#  datetime.date(2020, 8, 19): [70846, 88],
#  datetime.date(2020, 8, 20): [60779, 86],
#  datetime.date(2020, 8, 21): [53638, 71],
#  datetime.date(2020, 8, 22): [75515, 31],
#  datetime.date(2020, 8, 23): [27196, 41],
#  datetime.date(2020, 8, 24): [71020, 87],
#  datetime.date(2020, 8, 25): [65651, 85],
#  datetime.date(2020, 8, 26): [62560, 105],
#  datetime.date(2020, 8, 27): [66275, 108],
#  datetime.date(2020, 8, 28): [50559, 65],
#  datetime.date(2020, 8, 29): [54262, 53],
#  datetime.date(2020, 8, 30): [17683, 26],
#  datetime.date(2020, 8, 31): [70301, 71],
#  datetime.date(2020, 9, 1): [58137, 83],
#  datetime.date(2020, 9, 2): [69628, 69],
#  datetime.date(2020, 9, 3): [73146, 88],
#  datetime.date(2020, 9, 4): [76366, 116],
#  datetime.date(2020, 9, 5): [95303, 104],
#  datetime.date(2020, 9, 6): [22337, 61],
#  datetime.date(2020, 9, 7): [75029, 92],
#  datetime.date(2020, 9, 8): [60519, 91],
#  datetime.date(2020, 9, 9): [58606, 118],
#  datetime.date(2020, 9, 10): [59237, 99],
#  datetime.date(2020, 9, 11): [70657, 74],
#  datetime.date(2020, 9, 12): [99487, 61],
#  datetime.date(2020, 9, 13): [25985, 49],
#  datetime.date(2020, 9, 14): [53537, 100],
#  datetime.date(2020, 9, 15): [50165, 168],
#  datetime.date(2020, 9, 16): [52434, 150],
#  datetime.date(2020, 9, 17): [54956, 139],
#  datetime.date(2020, 9, 18): [68798, 129],
#  datetime.date(2020, 9, 19): [99938, 77],
#  datetime.date(2020, 9, 20): [27063, 60],
#  datetime.date(2020, 9, 21): [55195, 97],
#  datetime.date(2020, 9, 22): [47615, 93],
#  datetime.date(2020, 9, 23): [46873, 107],
#  datetime.date(2020, 9, 24): [46500, 90],
#  datetime.date(2020, 9, 25): [20384, 68],
#  datetime.date(2020, 9, 26): [55007, 74],
#  datetime.date(2020, 9, 27): [20458, 43],
#  datetime.date(2020, 9, 28): [42423, 106],
#  datetime.date(2020, 9, 29): [35654, 85],
#  datetime.date(2020, 9, 30): [52388, 81],
#  datetime.date(2020, 10, 1): [51840, 82],
#  datetime.date(2020, 10, 2): [71831, 64],
#  datetime.date(2020, 10, 3): [25996, 99],
#  datetime.date(2020, 10, 4): [25321, 23],
#  datetime.date(2020, 10, 5): [55001, 61],
#  datetime.date(2020, 10, 6): [47583, 121],
#  datetime.date(2020, 10, 7): [47110, 129],
#  datetime.date(2020, 10, 8): [58978, 139],
#  datetime.date(2020, 10, 9): [72812, 159],
#  datetime.date(2020, 10, 10): [77413, 93],
#  datetime.date(2020, 10, 11): [22213, 54],
#  datetime.date(2020, 10, 12): [51425, 112],
#  datetime.date(2020, 10, 13): [47827, 156],
#  datetime.date(2020, 10, 14): [45133, 173],
#  datetime.date(2020, 10, 15): [45560, 192],
#  datetime.date(2020, 10, 16): [36362, 198],
#  datetime.date(2020, 10, 17): [82193, 177],
#  datetime.date(2020, 10, 18): [16323, 94],
#  datetime.date(2020, 10, 19): [45083, 135],
#  datetime.date(2020, 10, 20): [40749, 194],
#  datetime.date(2020, 10, 21): [40870, 317],
#  datetime.date(2020, 10, 22): [40960, 319],
#  datetime.date(2020, 10, 23): [49779, 240],
#  datetime.date(2020, 10, 24): [69530, 215],
#  datetime.date(2020, 10, 25): [16612, 289],
#  datetime.date(2020, 10, 26): [22513, 227],
#  datetime.date(2020, 10, 27): [37614, 326],
#  datetime.date(2020, 10, 28): [39156, 359],
#  datetime.date(2020, 10, 29): [24865, 457],
#  datetime.date(2020, 10, 30): [53459, 366],
#  datetime.date(2020, 10, 31): [75652, 202],
#  datetime.date(2020, 11, 1): [10383, 258],
#  datetime.date(2020, 11, 2): [38195, 330],
#  datetime.date(2020, 11, 3): [28123, 499],
#  datetime.date(2020, 11, 4): [35306, 359],
#  datetime.date(2020, 11, 5): [39469, 430],
#  datetime.date(2020, 11, 6): [41994, 631],
#  datetime.date(2020, 11, 7): [58641, 501],
#  datetime.date(2020, 11, 8): [10261, 318],
#  datetime.date(2020, 11, 9): [31960, 447],
#  datetime.date(2020, 11, 10): [31810, 562],
#  datetime.date(2020, 11, 11): [32711, 609],
#  datetime.date(2020, 11, 12): [34740, 543],
#  datetime.date(2020, 11, 13): [47083, 414],
#  datetime.date(2020, 11, 14): [71245, 500],
#  datetime.date(2020, 11, 15): [11021, 197],
#  datetime.date(2020, 11, 16): [32985, 215],
#  datetime.date(2020, 11, 17): [34807, 574],
#  datetime.date(2020, 11, 18): [42215, 521],
#  datetime.date(2020, 11, 19): [26206, 667],
#  datetime.date(2020, 11, 20): [43821, 490],
#  datetime.date(2020, 11, 21): [68790, 293],
#  datetime.date(2020, 11, 22): [10685, 231],
#  datetime.date(2020, 11, 23): [34723, 355],
#  datetime.date(2020, 11, 24): [36227, 497],
#  datetime.date(2020, 11, 25): [37894, 491],
#  datetime.date(2020, 11, 26): [41441, 620],
#  datetime.date(2020, 11, 27): [88571, 103],
#  datetime.date(2020, 11, 28): [80158, 268],
#  datetime.date(2020, 11, 29): [10659, 468],
#  datetime.date(2020, 11, 30): [44037, 417],
#  datetime.date(2020, 12, 1): [35053, 430],
#  datetime.date(2020, 12, 2): [37233, 482],
#  datetime.date(2020, 12, 3): [42572, 620],
#  datetime.date(2020, 12, 4): [56718, 239],
#  datetime.date(2020, 12, 5): [70622, 207],
#  datetime.date(2020, 12, 6): [12834, 538],
#  datetime.date(2020, 12, 7): [47400, 610],
#  datetime.date(2020, 12, 8): [47765, 490],
#  datetime.date(2020, 12, 9): [31843, 590],
#  datetime.date(2020, 12, 10): [39280, 373],
#  datetime.date(2020, 12, 11): [52245, 593],
#  datetime.date(2020, 12, 12): [72175, 384],
#  datetime.date(2020, 12, 13): [7766, 395],
#  datetime.date(2020, 12, 14): [66757, 526],
#  datetime.date(2020, 12, 15): [68631, 870],
#  datetime.date(2020, 12, 16): [8984, 645],
#  datetime.date(2020, 12, 17): [9989, 817],
#  datetime.date(2020, 12, 18): [9249, 705],
#  datetime.date(2020, 12, 19): [7945, 601],
#  datetime.date(2020, 12, 20): [6337, 208],
#  datetime.date(2020, 12, 21): [10728, 266],
#  datetime.date(2020, 12, 22): [9696, 364],
#  datetime.date(2020, 12, 23): [9960, 601],
#  datetime.date(2020, 12, 24): [5164, 290],
#  datetime.date(2020, 12, 25): [5124, 0],
#  datetime.date(2020, 12, 26): [7973, 586],
#  datetime.date(2020, 12, 27): [6775, 357],
#  datetime.date(2020, 12, 28): [7900, 230],
#  datetime.date(2020, 12, 29): [10890, 537],
#  datetime.date(2020, 12, 30): [10065, 648],
#  datetime.date(2020, 12, 31): [6667, 346]}

# %% [markdown]
# ### Umwandlung der Fälle in Inzidenzen

# %% [markdown]
# Funktion to_incidences nimmt ein dictionary der Form d = {date: fälle}
#
# und erstellt ein passendes dictionary res = {date: incidence}

# %%
def to_incidences(d, einwohner):
    res = {}
    
    # add the first 7 days a 0
    cur_date = dt.date(2020,1,1)
    for i in range(7):
        res[cur_date] = 0
        cur_date += dt.timedelta(days = 1)
    
    for date in d:
        if(date >= dt.date(2020,12,25)):
            break
            
        fälle = 0
        cur_date = date
        fälle += d[cur_date]
        for delta in range(7):
            cur_date += dt.timedelta(days = 1)
            fälle += d[cur_date]
        
        incidence = (fälle*100000)/einwohner
        res[cur_date] = round(incidence)
    
    return res

# %%
d = {k:dic[k][1] for k in dic}
einwohner = 1488202
res = to_incidences(d, einwohner)
res
# Out:
# {datetime.date(2020, 1, 1): 0,
#  datetime.date(2020, 1, 2): 0,
#  datetime.date(2020, 1, 3): 0,
#  datetime.date(2020, 1, 4): 0,
#  datetime.date(2020, 1, 5): 0,
#  datetime.date(2020, 1, 6): 0,
#  datetime.date(2020, 1, 7): 0,
#  datetime.date(2020, 1, 8): 0,
#  datetime.date(2020, 1, 9): 0,
#  datetime.date(2020, 1, 10): 0,
#  datetime.date(2020, 1, 11): 0,
#  datetime.date(2020, 1, 12): 0,
#  datetime.date(2020, 1, 13): 0,
#  datetime.date(2020, 1, 14): 0,
#  datetime.date(2020, 1, 15): 0,
#  datetime.date(2020, 1, 16): 0,
#  datetime.date(2020, 1, 17): 0,
#  datetime.date(2020, 1, 18): 0,
#  datetime.date(2020, 1, 19): 0,
#  datetime.date(2020, 1, 20): 0,
#  datetime.date(2020, 1, 21): 0,
#  datetime.date(2020, 1, 22): 0,
#  datetime.date(2020, 1, 23): 0,
#  datetime.date(2020, 1, 24): 0,
#  datetime.date(2020, 1, 25): 0,
#  datetime.date(2020, 1, 26): 0,
#  datetime.date(2020, 1, 27): 0,
#  datetime.date(2020, 1, 28): 0,
#  datetime.date(2020, 1, 29): 0,
#  datetime.date(2020, 1, 30): 0,
#  datetime.date(2020, 1, 31): 0,
#  datetime.date(2020, 2, 1): 0,
#  datetime.date(2020, 2, 2): 0,
#  datetime.date(2020, 2, 3): 0,
#  datetime.date(2020, 2, 4): 0,
#  datetime.date(2020, 2, 5): 0,
#  datetime.date(2020, 2, 6): 0,
#  datetime.date(2020, 2, 7): 0,
#  datetime.date(2020, 2, 8): 0,
#  datetime.date(2020, 2, 9): 0,
#  datetime.date(2020, 2, 10): 0,
#  datetime.date(2020, 2, 11): 0,
#  datetime.date(2020, 2, 12): 0,
#  datetime.date(2020, 2, 13): 0,
#  datetime.date(2020, 2, 14): 0,
#  datetime.date(2020, 2, 15): 0,
#  datetime.date(2020, 2, 16): 0,
#  datetime.date(2020, 2, 17): 0,
#  datetime.date(2020, 2, 18): 0,
#  datetime.date(2020, 2, 19): 0,
#  datetime.date(2020, 2, 20): 0,
#  datetime.date(2020, 2, 21): 0,
#  datetime.date(2020, 2, 22): 0,
#  datetime.date(2020, 2, 23): 0,
#  datetime.date(2020, 2, 24): 0,
#  datetime.date(2020, 2, 25): 0,
#  datetime.date(2020, 2, 26): 0,
#  datetime.date(2020, 2, 27): 0,
#  datetime.date(2020, 2, 28): 0,
#  datetime.date(2020, 2, 29): 0,
#  datetime.date(2020, 3, 1): 0,
#  datetime.date(2020, 3, 2): 0,
#  datetime.date(2020, 3, 3): 0,
#  datetime.date(2020, 3, 4): 1,
#  datetime.date(2020, 3, 5): 1,
#  datetime.date(2020, 3, 6): 2,
#  datetime.date(2020, 3, 7): 1,
#  datetime.date(2020, 3, 8): 1,
#  datetime.date(2020, 3, 9): 3,
#  datetime.date(2020, 3, 10): 5,
#  datetime.date(2020, 3, 11): 6,
#  datetime.date(2020, 3, 12): 7,
#  datetime.date(2020, 3, 13): 10,
#  datetime.date(2020, 3, 14): 14,
#  datetime.date(2020, 3, 15): 15,
#  datetime.date(2020, 3, 16): 20,
#  datetime.date(2020, 3, 17): 28,
#  datetime.date(2020, 3, 18): 40,
#  datetime.date(2020, 3, 19): 50,
#  datetime.date(2020, 3, 20): 62,
#  datetime.date(2020, 3, 21): 71,
#  datetime.date(2020, 3, 22): 72,
#  datetime.date(2020, 3, 23): 77,
#  datetime.date(2020, 3, 24): 84,
#  datetime.date(2020, 3, 25): 91,
#  datetime.date(2020, 3, 26): 94,
#  datetime.date(2020, 3, 27): 99,
#  datetime.date(2020, 3, 28): 95,
#  datetime.date(2020, 3, 29): 96,
#  datetime.date(2020, 3, 30): 97,
#  datetime.date(2020, 3, 31): 112,
#  datetime.date(2020, 4, 1): 116,
#  datetime.date(2020, 4, 2): 109,
#  datetime.date(2020, 4, 3): 104,
#  datetime.date(2020, 4, 4): 96,
#  datetime.date(2020, 4, 5): 92,
#  datetime.date(2020, 4, 6): 88,
#  datetime.date(2020, 4, 7): 90,
#  datetime.date(2020, 4, 8): 80,
#  datetime.date(2020, 4, 9): 72,
#  datetime.date(2020, 4, 10): 69,
#  datetime.date(2020, 4, 11): 64,
#  datetime.date(2020, 4, 12): 60,
#  datetime.date(2020, 4, 13): 58,
#  datetime.date(2020, 4, 14): 56,
#  datetime.date(2020, 4, 15): 54,
#  datetime.date(2020, 4, 16): 49,
#  datetime.date(2020, 4, 17): 48,
#  datetime.date(2020, 4, 18): 45,
#  datetime.date(2020, 4, 19): 41,
#  datetime.date(2020, 4, 20): 38,
#  datetime.date(2020, 4, 21): 38,
#  datetime.date(2020, 4, 22): 36,
#  datetime.date(2020, 4, 23): 34,
#  datetime.date(2020, 4, 24): 31,
#  datetime.date(2020, 4, 25): 28,
#  datetime.date(2020, 4, 26): 27,
#  datetime.date(2020, 4, 27): 29,
#  datetime.date(2020, 4, 28): 31,
#  datetime.date(2020, 4, 29): 30,
#  datetime.date(2020, 4, 30): 29,
#  datetime.date(2020, 5, 1): 28,
#  datetime.date(2020, 5, 2): 26,
#  datetime.date(2020, 5, 3): 25,
#  datetime.date(2020, 5, 4): 25,
#  datetime.date(2020, 5, 5): 21,
#  datetime.date(2020, 5, 6): 19,
#  datetime.date(2020, 5, 7): 18,
#  datetime.date(2020, 5, 8): 18,
#  datetime.date(2020, 5, 9): 16,
#  datetime.date(2020, 5, 10): 15,
#  datetime.date(2020, 5, 11): 18,
#  datetime.date(2020, 5, 12): 17,
#  datetime.date(2020, 5, 13): 18,
#  datetime.date(2020, 5, 14): 18,
#  datetime.date(2020, 5, 15): 17,
#  datetime.date(2020, 5, 16): 15,
#  datetime.date(2020, 5, 17): 14,
#  datetime.date(2020, 5, 18): 13,
#  datetime.date(2020, 5, 19): 10,
#  datetime.date(2020, 5, 20): 9,
#  datetime.date(2020, 5, 21): 8,
#  datetime.date(2020, 5, 22): 8,
#  datetime.date(2020, 5, 23): 7,
#  datetime.date(2020, 5, 24): 7,
#  datetime.date(2020, 5, 25): 7,
#  datetime.date(2020, 5, 26): 9,
#  datetime.date(2020, 5, 27): 11,
#  datetime.date(2020, 5, 28): 10,
#  datetime.date(2020, 5, 29): 10,
#  datetime.date(2020, 5, 30): 10,
#  datetime.date(2020, 5, 31): 11,
#  datetime.date(2020, 6, 1): 10,
#  datetime.date(2020, 6, 2): 10,
#  datetime.date(2020, 6, 3): 7,
#  datetime.date(2020, 6, 4): 6,
#  datetime.date(2020, 6, 5): 6,
#  datetime.date(2020, 6, 6): 6,
#  datetime.date(2020, 6, 7): 4,
#  datetime.date(2020, 6, 8): 4,
#  datetime.date(2020, 6, 9): 5,
#  datetime.date(2020, 6, 10): 5,
#  datetime.date(2020, 6, 11): 5,
#  datetime.date(2020, 6, 12): 5,
#  datetime.date(2020, 6, 13): 4,
#  datetime.date(2020, 6, 14): 5,
#  datetime.date(2020, 6, 15): 4,
#  datetime.date(2020, 6, 16): 4,
#  datetime.date(2020, 6, 17): 4,
#  datetime.date(2020, 6, 18): 4,
#  datetime.date(2020, 6, 19): 5,
#  datetime.date(2020, 6, 20): 5,
#  datetime.date(2020, 6, 21): 6,
#  datetime.date(2020, 6, 22): 6,
#  datetime.date(2020, 6, 23): 6,
#  datetime.date(2020, 6, 24): 7,
#  datetime.date(2020, 6, 25): 7,
#  datetime.date(2020, 6, 26): 8,
#  datetime.date(2020, 6, 27): 8,
#  datetime.date(2020, 6, 28): 7,
#  datetime.date(2020, 6, 29): 8,
#  datetime.date(2020, 6, 30): 10,
#  datetime.date(2020, 7, 1): 9,
#  datetime.date(2020, 7, 2): 10,
#  datetime.date(2020, 7, 3): 10,
#  datetime.date(2020, 7, 4): 10,
#  datetime.date(2020, 7, 5): 10,
#  datetime.date(2020, 7, 6): 10,
#  datetime.date(2020, 7, 7): 11,
#  datetime.date(2020, 7, 8): 10,
#  datetime.date(2020, 7, 9): 10,
#  datetime.date(2020, 7, 10): 10,
#  datetime.date(2020, 7, 11): 9,
#  datetime.date(2020, 7, 12): 8,
#  datetime.date(2020, 7, 13): 9,
#  datetime.date(2020, 7, 14): 8,
#  datetime.date(2020, 7, 15): 7,
#  datetime.date(2020, 7, 16): 8,
#  datetime.date(2020, 7, 17): 9,
#  datetime.date(2020, 7, 18): 8,
#  datetime.date(2020, 7, 19): 9,
#  datetime.date(2020, 7, 20): 9,
#  datetime.date(2020, 7, 21): 9,
#  datetime.date(2020, 7, 22): 9,
#  datetime.date(2020, 7, 23): 9,
#  datetime.date(2020, 7, 24): 8,
#  datetime.date(2020, 7, 25): 7,
#  datetime.date(2020, 7, 26): 7,
#  datetime.date(2020, 7, 27): 7,
#  datetime.date(2020, 7, 28): 7,
#  datetime.date(2020, 7, 29): 7,
#  datetime.date(2020, 7, 30): 8,
#  datetime.date(2020, 7, 31): 8,
#  datetime.date(2020, 8, 1): 7,
#  datetime.date(2020, 8, 2): 7,
#  datetime.date(2020, 8, 3): 9,
#  datetime.date(2020, 8, 4): 9,
#  datetime.date(2020, 8, 5): 9,
#  datetime.date(2020, 8, 6): 10,
#  datetime.date(2020, 8, 7): 10,
#  datetime.date(2020, 8, 8): 9,
#  datetime.date(2020, 8, 9): 9,
#  datetime.date(2020, 8, 10): 10,
#  datetime.date(2020, 8, 11): 11,
#  datetime.date(2020, 8, 12): 13,
#  datetime.date(2020, 8, 13): 16,
#  datetime.date(2020, 8, 14): 17,
#  datetime.date(2020, 8, 15): 18,
#  datetime.date(2020, 8, 16): 20,
#  datetime.date(2020, 8, 17): 26,
#  datetime.date(2020, 8, 18): 28,
#  datetime.date(2020, 8, 19): 31,
#  datetime.date(2020, 8, 20): 34,
#  datetime.date(2020, 8, 21): 35,
#  datetime.date(2020, 8, 22): 33,
#  datetime.date(2020, 8, 23): 34,
#  datetime.date(2020, 8, 24): 37,
#  datetime.date(2020, 8, 25): 37,
#  datetime.date(2020, 8, 26): 40,
#  datetime.date(2020, 8, 27): 41,
#  datetime.date(2020, 8, 28): 40,
#  datetime.date(2020, 8, 29): 39,
#  datetime.date(2020, 8, 30): 38,
#  datetime.date(2020, 8, 31): 40,
#  datetime.date(2020, 9, 1): 40,
#  datetime.date(2020, 9, 2): 39,
#  datetime.date(2020, 9, 3): 38,
#  datetime.date(2020, 9, 4): 38,
#  datetime.date(2020, 9, 5): 41,
#  datetime.date(2020, 9, 6): 42,
#  datetime.date(2020, 9, 7): 46,
#  datetime.date(2020, 9, 8): 47,
#  datetime.date(2020, 9, 9): 50,
#  datetime.date(2020, 9, 10): 52,
#  datetime.date(2020, 9, 11): 51,
#  datetime.date(2020, 9, 12): 47,
#  datetime.date(2020, 9, 13): 43,
#  datetime.date(2020, 9, 14): 46,
#  datetime.date(2020, 9, 15): 51,
#  datetime.date(2020, 9, 16): 55,
#  datetime.date(2020, 9, 17): 56,
#  datetime.date(2020, 9, 18): 58,
#  datetime.date(2020, 9, 19): 59,
#  datetime.date(2020, 9, 20): 59,
#  datetime.date(2020, 9, 21): 62,
#  datetime.date(2020, 9, 22): 61,
#  datetime.date(2020, 9, 23): 57,
#  datetime.date(2020, 9, 24): 53,
#  datetime.date(2020, 9, 25): 48,
#  datetime.date(2020, 9, 26): 45,
#  datetime.date(2020, 9, 27): 42,
#  datetime.date(2020, 9, 28): 46,
#  datetime.date(2020, 9, 29): 45,
#  datetime.date(2020, 9, 30): 44,
#  datetime.date(2020, 10, 1): 42,
#  datetime.date(2020, 10, 2): 41,
#  datetime.date(2020, 10, 3): 43,
#  datetime.date(2020, 10, 4): 39,
#  datetime.date(2020, 10, 5): 40,
#  datetime.date(2020, 10, 6): 41,
#  datetime.date(2020, 10, 7): 44,
#  datetime.date(2020, 10, 8): 48,
#  datetime.date(2020, 10, 9): 53,
#  datetime.date(2020, 10, 10): 55,
#  datetime.date(2020, 10, 11): 52,
#  datetime.date(2020, 10, 12): 58,
#  datetime.date(2020, 10, 13): 65,
#  datetime.date(2020, 10, 14): 68,
#  datetime.date(2020, 10, 15): 72,
#  datetime.date(2020, 10, 16): 76,
#  datetime.date(2020, 10, 17): 78,
#  datetime.date(2020, 10, 18): 78,
#  datetime.date(2020, 10, 19): 83,
#  datetime.date(2020, 10, 20): 89,
#  datetime.date(2020, 10, 21): 99,
#  datetime.date(2020, 10, 22): 109,
#  datetime.date(2020, 10, 23): 112,
#  datetime.date(2020, 10, 24): 114,
#  datetime.date(2020, 10, 25): 121,
#  datetime.date(2020, 10, 26): 130,
#  datetime.date(2020, 10, 27): 143,
#  datetime.date(2020, 10, 28): 154,
#  datetime.date(2020, 10, 29): 163,
#  datetime.date(2020, 10, 30): 167,
#  datetime.date(2020, 10, 31): 164,
#  datetime.date(2020, 11, 1): 167,
#  datetime.date(2020, 11, 2): 170,
#  datetime.date(2020, 11, 3): 188,
#  datetime.date(2020, 11, 4): 190,
#  datetime.date(2020, 11, 5): 195,
#  datetime.date(2020, 11, 6): 207,
#  datetime.date(2020, 11, 7): 216,
#  datetime.date(2020, 11, 8): 223,
#  datetime.date(2020, 11, 9): 236,
#  datetime.date(2020, 11, 10): 252,
#  datetime.date(2020, 11, 11): 259,
#  datetime.date(2020, 11, 12): 272,
#  datetime.date(2020, 11, 13): 270,
#  datetime.date(2020, 11, 14): 262,
#  datetime.date(2020, 11, 15): 241,
#  datetime.date(2020, 11, 16): 234,
#  datetime.date(2020, 11, 17): 243,
#  datetime.date(2020, 11, 18): 240,
#  datetime.date(2020, 11, 19): 244,
#  datetime.date(2020, 11, 20): 240,
#  datetime.date(2020, 11, 21): 232,
#  datetime.date(2020, 11, 22): 214,
#  datetime.date(2020, 11, 23): 225,
#  datetime.date(2020, 11, 24): 244,
#  datetime.date(2020, 11, 25): 238,
#  datetime.date(2020, 11, 26): 245,
#  datetime.date(2020, 11, 27): 207,
#  datetime.date(2020, 11, 28): 192,
#  datetime.date(2020, 11, 29): 204,
#  datetime.date(2020, 11, 30): 216,
#  datetime.date(2020, 12, 1): 221,
#  datetime.date(2020, 12, 2): 220,
#  datetime.date(2020, 12, 3): 229,
#  datetime.date(2020, 12, 4): 203,
#  datetime.date(2020, 12, 5): 210,
#  datetime.date(2020, 12, 6): 229,
#  datetime.date(2020, 12, 7): 238,
#  datetime.date(2020, 12, 8): 243,
#  datetime.date(2020, 12, 9): 254,
#  datetime.date(2020, 12, 10): 246,
#  datetime.date(2020, 12, 11): 245,
#  datetime.date(2020, 12, 12): 254,
#  datetime.date(2020, 12, 13): 267,
#  datetime.date(2020, 12, 14): 266,
#  datetime.date(2020, 12, 15): 284,
#  datetime.date(2020, 12, 16): 294,
#  datetime.date(2020, 12, 17): 309,
#  datetime.date(2020, 12, 18): 332,
#  datetime.date(2020, 12, 19): 332,
#  datetime.date(2020, 12, 20): 320,
#  datetime.date(2020, 12, 21): 312,
#  datetime.date(2020, 12, 22): 301,
#  datetime.date(2020, 12, 23): 283,
#  datetime.date(2020, 12, 24): 259,
#  datetime.date(2020, 12, 25): 204,
#  datetime.date(2020, 12, 26): 196,
#  datetime.date(2020, 12, 27): 180,
#  datetime.date(2020, 12, 28): 181,
#  datetime.date(2020, 12, 29): 199,
#  datetime.date(2020, 12, 30): 218,
#  datetime.date(2020, 12, 31): 201}

# %% [markdown]
# ### Berechnung der Korrelation

# %%
peds = [p for p,i in dic.values()]
fälle = [f for p,f in dic.values()]
incs = [i for i in res.values()]
dates = dic[date]
dates
# Out:
# [53459, 366]

# %% [markdown]
# # Grundlegende Funktionen zur Betrachtung von spezifischen Zeiträumen
#
# Im Folgenden geht es um die Betrachtung von Fußgängerzahlen und Coronainzidenzen während spezifischen Zeiträumen im Jahr 2020. Dazu zählen Lockdowns, Ferienzeiten oder Feste wie Fastnacht.
# Dazu werden drei Funktionen definiert:
#
# 1. Die Funktionen calcDay(date) nimmt ein Datum im Format "dd-mm-yyyy" entgegen und gibt zurück, der wie vielte Tag des Jahres es ist. Dadurch kann man die relevanten Tage im Array ausmachen und für die Zeiträume zwischen Startdatum und Enddatum Visualisierungen und Analysen durchführen.
#
#
# 2. Die Funktion calcCor(startdate, enddate) nimmt ein Startdatum und Enddatum entgegen und berechnet mithilfe der Methode corrcoef(), ob die Fußgängeranzahl und die Coronainzidenzen in dem gewählten Zeitraum korrelieren. Das Ergebnis ist eine Zahl zwischen -1 und 1. Bei einer Zahl Nahe 0 korrelieren die Daten nicht, bei -1 handelt es sich um eine negative Korrelation und bei einem Ergebnis gegen 1 handelt es sich um eine positive Korrelation.
#
#
# 3. Die letzte Funktion plottimeframe(start, end) erstellt einen Graphen mit den Fußgänger- und Coronadaten für den ausgewählten Zeitraum. Auf der x-Achse befindet sich die Zeit. Auf der y-Achse befinden sich die Fußgängeranzahl (blau) und die Coronainzidenzen (rot)

# %%
from datetime import datetime

def calcDay(date):
    adate = datetime.strptime(date,"%d-%m-%Y")
    adate = adate.timetuple().tm_yday
    return adate

# %%
def calcCor(startdate, enddate):
    return np.corrcoef(peds[startdate:enddate], incs[startdate:enddate])

# %%
import matplotlib.pyplot as plt  

def plottimeframe(start, end):
    x = list(d.keys())

    x = x[start: end]

    y1 = list(peds[start:end])
    y2 = list(fälle[start:end])
    y3 = list(incs[start:end])

    fig, ax1 = plt.subplots(figsize=(12, 3))

    ax1.set_xlabel('time')
    ax1.set_ylabel('pedestrians', color='b')
    ax1.plot_date(x, y1, linestyle='-', color='b')

    ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

    ax2.set_ylabel('incidences', color='r')
    ax2.plot_date(x, y3, linestyle='-', color='r')

    fig.tight_layout()  # otherwise the right y-label is slightly clipped
    plt.show()

# %% [markdown]
# # Betrachtung: 1. Lockdown März
#
# Im Folgenden wird der erste Lockdown betrachtet. Am 27. Januar wurde der erste Coronafall in Deutschland gemeldet. Am 22. März wurde der erste Lockdown einberufen. Die Betrachtung beginnt am 01. März und endet am 1. Mai. Eine frühere Betrachtung würde keine bedeutenden Ergebnisse liefern, da zu dem Zeitpunkt kaum Fälle aufgetreten sind.
# Der erste Schritt ist das Errechnen des Zeitraums mithilfe der calcDay Funktion und die Darstellung mithilfe der Bibliothek matplotlib.

# %%
startdate = calcDay("01-03-2020")
enddate = calcDay("01-06-2020")
plottimeframe(startdate, enddate)

# %%
test = calcCor(startdate, enddate)
print(test)
# Out:
# [[ 1.        -0.7096062]
#  [-0.7096062  1.       ]]

# %% [markdown]
# ### Ergebnis
#
# Anhand der Korrelationsfunktion ist zu erkennen, dass die beiden Werte Fußgängeranzahl und Corona-Inzidenz negativ korrelieren. Daraus und anhand des obigen Graphen ist abzuleiten, dass die Fußgäger bei höherer Inzidenz wenig unterwegs waren.

# %% [markdown]
# # Betrachtung: 2. Lockdown Dezember
#
# Hier wird der zweite Lockdown betrachtet. Am 16. Dezember wurde ein starker Lockdown einberufen. Die Betrachtung beginnt am 30. November und endet am 31. Dezember.
# Der erste Schritt ist wieder das Errechnen des Zeitraums mithilfe der calcDay Funktion und die Darstellung mithilfe der Bibliothek matplotlib.

# %%
startdate = calcDay("30-11-2020")
enddate = calcDay("31-12-2020")
plottimeframe(startdate, enddate)

# %%
test = calcCor(startdate, enddate)
print(test)
# Out:
# [[ 1.         -0.13163236]
#  [-0.13163236  1.        ]]

# %% [markdown]
# ### Ergebnis
#
# Anhand der Korrelationsfunktion ist zu erkennen, dass die beiden Werte Fußgängeranzahl und Corona-Inzidenz im Dezember negativ korrelieren. Anhand des Graphen ist klar zu erkennen, dass die Fußgängerzahl ab dem Lockdown am 16. Dezember drastisch gesunken ist. Mit ein wenig Verzögerug ist die Inzidenz gesunken.

# %% [markdown]
# # Betrachtung: Sommerferien

# %%
startdate = calcDay("27-07-2020")
enddate = calcDay("07-09-2020")
plottimeframe(startdate, enddate)

# %%
test = calcCor(startdate, enddate)
print(test)
# Out:
# [[1.         0.02611959]
#  [0.02611959 1.        ]]

# %% [markdown]
# ### Ergebnis
#
# Anhand der Korrelationsfunktion ist zu erkennen, dass die beiden Werte Fußgängeranzahl und Corona-Inzidenz kaum korrelieren. Die Inzidenzen steigen stark an während die Anzahl der Fußgänger einen zymlich konstanten Zyklus aufweist.
